# %%
from es_notebook_utils import FDSNChannelSelector
#selector = FDSNChannelSelector("https://service.earthscope.org")
selector = FDSNChannelSelector(
        default_network="TA",
        default_channel="BDF",
        default_starttime="2015-01-01",
        default_endtime="2024-02-01",
    )
selector.show()

# %%
print(selector.selected)
# Out:
# [('TA', '109C', '--', 'LHZ', UTCDateTime(2015, 1, 1, 0, 0), UTCDateTime(2018, 8, 21, 14, 40)), ('TA', '121A', '--', 'LHZ', UTCDateTime(2015, 1, 1, 0, 0), UTCDateTime(2015, 8, 17, 15, 35)), ('TA', '121A', '--', 'LHZ', UTCDateTime(2015, 8, 17, 15, 35), UTCDateTime(2015, 8, 18, 13, 30)), ('TA', '121A', '--', 'LHZ', UTCDateTime(2015, 8, 18, 13, 30), UTCDateTime(2016, 6, 28, 18, 26)), ('TA', '121A', '--', 'LHZ', UTCDateTime(2016, 6, 28, 18, 26), UTCDateTime(2016, 12, 6, 0, 0)), ('TA', '121A', '--', 'LHZ', UTCDateTime(2016, 12, 6, 0, 0), UTCDateTime(2019, 3, 8, 15, 35)), ('TA', '214A', '--', 'LHZ', UTCDateTime(2015, 1, 1, 0, 0), UTCDateTime(2015, 6, 30, 15, 44, 59)), ('TA', '214A', '--', 'LHZ', UTCDateTime(2015, 6, 30, 15, 45), UTCDateTime(2018, 9, 7, 20, 30)), ('TA', '435B', '--', 'LHZ', UTCDateTime(2015, 1, 1, 0, 0), UTCDateTime(2016, 1, 26, 17, 0)), ('TA', '435B', '--', 'LHZ', UTCDateTime(2016, 1, 26, 17, 0), UTCDateTime(2016, 9, 29, 20, 0)), ('TA', '435B', '--', 'LHZ', UTCDateTime(2016
# ...

# %%
selector.selected_inventory()
# Out:
# Inventory created at 2026-06-26T20:12:28.362214Z
# 	Created by: ObsPy 1.5.0
# 		    https://www.obspy.org
# 	Sending institution: EarthScope (EarthScope)
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
